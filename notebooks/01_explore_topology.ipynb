# %% [markdown]
# # 01 — Explore NVL72 Topology
#
# Load the generated NVL72 bipartite topology and inspect basic structure.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.topology.graph import load_topology

topo = load_topology()
print(topo.metadata)
print("nodes", topo.graph.number_of_nodes(), "edges", topo.graph.number_of_edges())
print("tray0", topo.get_gpus_in_tray("node_0"))
print("shared switches(gpu_0, gpu_40)", len(topo.get_path_between_gpus("gpu_0", "gpu_40")))
# Out:
# {'name': 'NVL72 GB200 UltraServer', 'source': 'NVIDIA NVL72 AI Factory Reference Architecture', 'url': 'https://docs.nvidia.com/enterprise-reference-architectures/nvl72-ai-factory/latest/components.html', 'num_gpus': 72, 'num_nvswitches': 18, 'num_compute_nodes': 18, 'gpus_per_node': 4, 'total_nvlinks': 1296}
# nodes 90 edges 1296
# tray0 ['gpu_0', 'gpu_1', 'gpu_2', 'gpu_3']
# shared switches(gpu_0, gpu_40) 18
