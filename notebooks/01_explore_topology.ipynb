# %% [markdown]
# # 01 — Explore NVL72 Topology
#
# Placeholder notebook. Filled in after Step 2 generates `data/topology/nvl72_topology.json`.

# %%
# from src.topology.graph import load_topology
# g = load_topology()
# print(g.number_of_nodes(), g.number_of_edges())
